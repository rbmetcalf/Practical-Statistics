# %%
#Tutorial # 03

## The central limit theorem holds that the sum of a large number of identically 
## distributed random numbers will be normally distributed no matter how the 
## individual numbers are distributed.
##
## In lecture we proved this and saw how the pdf for the sum of variables 
## can be found numerically from the pdf of the individuals using the Fourier 
## transform.
##
## Now we will verify the central limit theorem by numerically experiment :

from scipy.stats import lognorm
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np


# 1) Create 1000 uniform random numbers between -1 and 1 using numpy.rand
uniform0 = np.array(np.random.uniform(-1, 1, 1000))
uniform1 = np.array(np.random.uniform(-1, 1, 1000))
uniform2 = np.array(np.random.uniform(-1, 1, 1000))
uniform3 = np.array(np.random.uniform(-1, 1, 1000))
uniform4 = np.array(np.random.uniform(-1, 1, 1000))
uniform5 = np.array(np.random.uniform(-1, 1, 1000))
uniform6 = np.array(np.random.uniform(-1, 1, 1000))
uniform7 = np.array(np.random.uniform(-1, 1, 1000))
uniform8 = np.array(np.random.uniform(-1, 1, 1000))
uniform9 = np.array(np.random.uniform(-1, 1, 1000))

       # make histogram of numbers
plt.hist(uniform0, bins=20, normed=True)
plt.title('Uniform distribution')

plt.show()


# 2) Make 1000 sums of 3 uniform random numbers between -1 and 1
sum3 = uniform0 + uniform1 + uniform2

mean3 = sum3.mean()
sigma3 = sum3.std()
var3 = sum3.std() ** 2
#noraldist=np.random.normal(loc=mean, scale=variance, size=1000)
       # make histogram of numbers
Hist3 = plt.hist(sum3, bins=20, normed=True)
x = np.linspace(mean3 - 3*sigma3, mean3 + 3*sigma3, 100)
G3 = plt.plot(x,mlab.normpdf(x, mean3, sigma3))
plt.title('Uniform distribution with 3 sum')
plt.show()


       # draw normal distribution with the same man and variance over histogram 
       # (What should the variance be?)

# 3) Make 1000 sums of 10 uniform random numbers between -1 and 1
sum10 = uniform0 + uniform1 + uniform2 + uniform3 + uniform4 + uniform5 + uniform6 +uniform7 + uniform8 + uniform9

mean10 = sum10.mean()
sigma10 = sum10.std()
var10 = sum10.std() ** 2
       # make histogram of numbers
Hist10 = plt.hist(sum10, bins=20, normed=True)
x = np.linspace(mean10 - 3*sigma10, mean10 + 3*sigma10, 100)
G10 = plt.plot(x,mlab.normpdf(x, mean10, sigma10))
plt.title('Uniform distribution with 10 sum')
plt.show()

       # draw normal distribution with the same variance over histogram

# 4) Do 1 through 3 for a lognormal distribution instead of uniform.  The 
#    lognormal distribution can be found in the scipy.stats package. 

lognormal0 = np.array(np.random.lognormal(0, 1, 1000))
lognormal1 = np.array(np.random.lognormal(0, 1, 1000))
lognormal2 = np.array(np.random.lognormal(0, 1, 1000))
lognormal3 = np.array(np.random.lognormal(0, 1, 1000))
lognormal4 = np.array(np.random.lognormal(0, 1, 1000))
lognormal5 = np.array(np.random.lognormal(0, 1, 1000))
lognormal6 = np.array(np.random.lognormal(0, 1, 1000))
lognormal7 = np.array(np.random.lognormal(0, 1, 1000))
lognormal8 = np.array(np.random.lognormal(0, 1, 1000))
lognormal9 = np.array(np.random.lognormal(0, 1, 1000))

s1 = lognormal0.std()

ist = plt.hist(lognormal, bins=20, normed=True)
x = np.linspace(0.1, 20, 1000)
#g1 = plt.plot(x,mlab.normpdf(x, mean10, sigma10)
plt.title('Logaritmic distribution')
plt.show()

log3 = (lognormal0 + lognormal1 + lognormal2)/3.

m3 = log3.mean()
s3 = log3.std()
v3 = log3.std() ** 2

       # make histogram of numbers
ist3 = plt.hist(log3, bins=20, normed=True)
x = np.linspace(0.0, 10, 1000)
g3 = plt.plot(x,mlab.normpdf(x, m3, s3))
plt.title('Logaritmic distribution with 3 sum')
plt.show()


log10 = (lognormal0 + lognormal1 + lognormal2 + lognormal3 + lognormal4 + lognormal5 + lognormal6 + lognormal7 + lognormal8 + lognormal9)/10.

    
log10 = np.array(log10)
m10 = log10.mean()
s10 = log10.std()

       # make histogram of numbers
ist10 = plt.hist(log10, bins=20, normed=True)
x = np.linspace(0.0, 10, 1000)
g10 = plt.plot(x,mlab.normpdf(x, m10, s10))
plt.title('Logaritmic distribution with 10 sum')
plt.show()
# Out:
# /home/STUDENTI/marcello.crosta/.local/lib/python2.7/site-packages/ipykernel_launcher.py:48: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# /home/STUDENTI/marcello.crosta/.local/lib/python2.7/site-packages/ipykernel_launcher.py:65: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# /home/STUDENTI/marcello.crosta/.local/lib/python2.7/site-packages/ipykernel_launcher.py:102: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# /home/STUDENTI/marcello.crosta/.local/lib/python2.7/site-packages/ipykernel_launcher.py:117: MatplotlibDeprecationWarning: scipy.stats.norm.pdf

# %%
np.random.lognormal(0.0, 1, 1000)
# Out:
# array([  0.83189637,   0.63287365,   0.48192311,   0.57444495,
#          1.0840775 ,   0.26216291,   1.53496358,   1.23301094,
#          0.36753806,   2.3687163 ,   0.30133233,   2.93186904,
#          3.12793544,   0.23112157,   3.15426021,   0.36577615,
#          0.85384697,   1.36193463,   0.84287266,   0.42692136,
#          2.14637964,   1.29567983,   0.99419349,   2.99810106,
#          0.74882677,   0.94833683,   1.0019167 ,   1.26761249,
#          0.76651521,   0.9485705 ,   3.14620292,   0.45595574,
#          1.18876841,   1.65198984,   0.45987569,   0.72216371,
#          1.46220666,   1.05632813,   0.48557418,   7.29616552,
#          1.64754063,   0.06544176,   1.64507518,   0.7385469 ,
#          2.10788635,   0.53901213,   3.59013214,   1.24704798,
#          0.88748516,   3.1713885 ,   2.56024175,   0.61292161,
#          1.57258776,   4.31530025,   1.51062636,   4.01690406,
#          2.00686114,   2.19224563,   1.08247827,   0.46052641,
# ...
