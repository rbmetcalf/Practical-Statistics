# %%
#Tutorial # 03

## The central limit theorem holds that the sum of a large number of identically 
## distributed random numbers will be normally distributed no matter how the 
## individual numbers are distributed.
##
## In lecture we proved this and saw how the pdf for the sum of variables 
## can be found numerically from the pdf of the individuals using the Fourier 
## transform.
##
## Now we will verify the central limit theorem by numerically experiment :

# 1) Create 1000 uniform random numbers between -1 and 1 using numpy.rand
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

size = 1000

sample = np.random.uniform(-1.,1.,size)

       # make histogram of numbers
plt.hist(sample)
plt.title('Uniform sample')
plt.show()

# 2) Make 1000 sums of 3 uniform random numbers between -1 and 1
zero = np.random.uniform(-1,1,size)
on = np.random.uniform(-1,1,size)
tw = np.random.uniform(-1,1,size)
sums = zero + one + two 
    
       # make histogram of numbers
plt.hist(sums,bins = 40, color = 'b',normed = True,label = 'uniform')
       # draw normal distribution with the same man and variance over histogram 
       # (What should the variance be?)
mean = np.mean(sums)
variance = np.var(sums)
sigma = np.std(sums)

x = np.linspace(mean - 3*sigma, mean + 3*sigma, 100)
plt.plot(x,mlab.normpdf(x, mean, sigma),color = 'red',label = 'normal')
plt.legend(loc='upper right')
plt.title('Sum on 3 vectors')
plt.show()

# 3) Make 1000 sums of 10 uniform random numbers between -1 and 1
one = np.random.uniform(-1,1,size)
two = np.random.uniform(-1,1,size)
three = np.random.uniform(-1,1,size)
four = np.random.uniform(-1,1,size)
five = np.random.uniform(-1,1,size)
six = np.random.uniform(-1,1,size)
seven = np.random.uniform(-1,1,size)
eight = np.random.uniform(-1,1,size)
nine = np.random.uniform(-1,1,size)
ten = np.random.uniform(-1,1,size)

numbers = one + two + three + four + five + six + seven + eight + nine + ten 
       # make histogram of numbers
plt.hist(numbers,bins = 40, color = 'cyan',normed = True, label = 'uniform')
       # draw normal distribution with the same variance over histogram
meanTen = np.mean(numbers)
varianceTen = np.var(numbers)
sigmaTen = np.std(numbers)
xTen = np.linspace(meanTen - 3*sigmaTen, meanTen + 3*sigmaTen, 100)
plt.plot(xTen, mlab.normpdf(xTen,meanTen,sigmaTen),color = 'magenta', label = 'normal')
plt.title('Sum on 10 vectors')
plt.legend(loc = 'upper right')
plt.show()

# 4) Do 1 through 3 for a lognormal distribution instead of uniform.  The 
#    lognormal distribution can be found in the scipy.stats package. 
sampleLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
plt.hist(sampleLog)
plt.title('Lognormal sample')
plt.show()

zeroLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
oneLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
twoLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
sumsLog = zeroLog + oneLog + twoLog 

plt.hist(sumsLog,bins = 40, color = 'b',normed = True,label = 'lognormal')
meanLog = np.mean(sumsLog)
varianceLog = np.var(sumsLog)
sigmaLog = np.std(sumsLog)

xLog = np.linspace(meanLog - 3*sigmaLog, meanLog + 3*sigmaLog, 100)
plt.plot(xLog,mlab.normpdf(xLog, meanLog, sigmaLog),color = 'red',label = 'normal')
plt.legend(loc='upper right')
plt.title('Sum on 3 vectors with lognormal')
plt.show()

onLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
twLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
threeLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
fourLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
fiveLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
sixLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
sevenLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
eightLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
nineLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)
tenLog = np.random.lognormal(mean = 0, sigma = 1.0, size = size)

sumsTenLog = onLog + twLog + threeLog + fourLog + fiveLog + sixLog + sevenLog + eightLog + nineLog + tenLog

plt.hist(sumsTenLog,bins = 40, color = 'cyan',normed = True, label = 'lognormal')

meanTenLog = np.mean(sumsTenLog)
varianceTenLog = np.var(sumsTenLog)
sigmaTenLog = np.std(sumsTenLog)
xTenLog = np.linspace(meanTenLog - 3*sigmaTenLog, meanTenLog + 3*sigmaTenLog, 100)
plt.plot(xTenLog, mlab.normpdf(xTenLog,meanTenLog,sigmaTenLog),color = 'magenta', label = 'normal')
plt.title('Sum on 10 vectors with lognormal')
plt.legend(loc = 'upper right')
plt.show()
